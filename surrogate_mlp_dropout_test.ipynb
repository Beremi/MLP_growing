# %% [markdown]
# # Surrogate MLP with LayerNorm & Dropout
# Train and evaluate the new `SurrogateMLP` architecture on the DA chain data.
# Use the configuration cell below to pick the data slice, hidden structure, loss, and dropout;
# the notebook will report the L1 log-posterior error on the tail of the chain (index ≥ 50,000).

# %% [markdown]
# **Workflow**
# 1. Adjust the configuration cell (data path, number of chain steps, loss type, etc.).
# 2. Run the data-loading cell to fetch `par`, `obs`, `chain`, `props`, and `logpi`.
# 3. Execute the preprocessing + training cells to fit `SurrogateMLP`.
# 4. Inspect the training history and final metrics, including the requested L1 logπ error
#    computed on the remainder of the chain beyond index 50,000.

# %%
import math
from pathlib import Path
from typing import Sequence, Literal

import numpy as np
import torch
from torch import nn

from test_mlp import (
    load_data,
    collect_training_indices,
    standardize_features,
    train_mlp,
    compute_logpi_l1_error,
)

# %%
ActivationName = Literal["silu", "relu", "tanh", "gelu"]


def _make_activation(name: ActivationName) -> nn.Module:
    name = name.lower()
    if name == "silu":
        return nn.SiLU()
    if name == "relu":
        return nn.ReLU()
    if name == "tanh":
        return nn.Tanh()
    if name == "gelu":
        return nn.GELU()
    raise ValueError(f"Unknown activation: {name}")


class SurrogateMLP(nn.Module):
    """Flexible MLP with optional LayerNorm and dropout."""

    def __init__(
        self,
        input_dim: int,
        output_dim: int,
        hidden_dims: Sequence[int],
        dropout: float = 0.1,
        activation: ActivationName = "silu",
        use_layer_norm: bool = True,
    ) -> None:
        super().__init__()
        if len(hidden_dims) == 0:
            raise ValueError("hidden_dims must be non-empty")
        self.input_dim = input_dim
        self.output_dim = output_dim
        self.hidden_dims = list(hidden_dims)
        self.dropout_p = float(dropout)
        self.use_layer_norm = bool(use_layer_norm)
        self.activation_name: ActivationName = activation.lower()  # type: ignore

        layers = []
        dims = [input_dim] + list(hidden_dims)
        for in_dim, out_dim in zip(dims[:-1], dims[1:]):
            block = []
            block.append(nn.Linear(in_dim, out_dim))
            if self.use_layer_norm:
                block.append(nn.LayerNorm(out_dim))
            block.append(_make_activation(self.activation_name))
            if self.dropout_p > 0.0:
                block.append(nn.Dropout(p=self.dropout_p))
            layers.append(nn.Sequential(*block))

        self.blocks = nn.ModuleList(layers)
        self.out_layer = nn.Linear(hidden_dims[-1], output_dim)
        self._init_weights()

    def _init_weights(self) -> None:
        nonlinearity = "relu" if self.activation_name in ("relu", "silu", "gelu") else "tanh"
        for module in self.modules():
            if isinstance(module, nn.Linear):
                nn.init.kaiming_uniform_(module.weight, a=math.sqrt(5), nonlinearity=nonlinearity)
                if module.bias is not None:
                    fan_in, _ = nn.init._calculate_fan_in_and_fan_out(module.weight)
                    bound = 1 / math.sqrt(fan_in) if fan_in > 0 else 0.0
                    nn.init.uniform_(module.bias, -bound, bound)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        h = x
        for block in self.blocks:
            h = block(h)
        return self.out_layer(h)

# %%
# --- Configuration ---

DATA_PATH = Path('data1.h5')
SIGMA_PRIOR = 1.0
SIGMA_LIK = 0.3
TRAIN_STEPS = 8000  # number of chain steps (chain + props) for training
STANDARDIZE_INPUTS = True

HIDDEN_DIMS = [1024, 1024, 1024]
DROPOUT_P = 0.5
USE_LAYER_NORM = True
ACTIVATION = 'silu'

LOSS_NAME = 'mse'       # 'l1', 'mse', or 'mixed'
LOSS_DOMAIN = 'obs'    # 'obs' or 'logpi'
TRAIN_LOOPS = 80
ADAM_EPOCHS = 2000
ADAM_LR = 1.1e-3
ADAM_PATIENCE = 1000
LBFGS_STEPS = 100
TOL = 1e-5
BATCH_SIZE = 32
BATCH_GROWTH = 1.4    # e.g. 1.2 to grow batch every loop
LOOP_IMPROVEMENT_PCT = -0.01

EVAL_TAIL_START = 50000
SEED = 123
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

np.random.seed(SEED)
torch.manual_seed(SEED)
np.set_printoptions(precision=4, suppress=True)
print(f'Using device: {DEVICE}')
# Out:
# Using device: cuda

# %%
# --- Load data ---
par, obs, y_obs, chain, props, logpi_true = load_data(str(DATA_PATH), SIGMA_PRIOR, SIGMA_LIK)
print(f'par shape   : {par.shape}')
print(f'obs shape   : {obs.shape}')
print(f'chain length: {chain.shape[0]}')
print(f'props length: {props.shape[0]}')
# Out:
# [data] Loaded 'logpi' from file.
# [data] par shape   : (28324, 30)
# [data] obs shape   : (28324, 52)
# [data] y_obs shape : (52,)
# [data] chain shape : (56646,)
# [data] props shape : (56646,)
# par shape   : (28324, 30)
# obs shape   : (28324, 52)
# chain length: 56646
# props length: 56646

# %%
# --- Prepare training tensors ---

train_idx = collect_training_indices(chain, props, TRAIN_STEPS)
X_train_raw = par[train_idx]
y_train = obs[train_idx]
logpi_train = logpi_true[train_idx]

if STANDARDIZE_INPUTS:
    X_train, x_mean, x_std = standardize_features(X_train_raw)
else:
    X_train = X_train_raw
    x_mean = np.zeros(X_train_raw.shape[1], dtype=X_train_raw.dtype)
    x_std = np.ones(X_train_raw.shape[1], dtype=X_train_raw.dtype)

print(f'unique training samples: {X_train.shape[0]}')
print(f'feature dimension     : {X_train.shape[1]}')
print(f'observation dimension : {y_train.shape[1]}')
# Out:
# unique training samples: 4001
# feature dimension     : 30
# observation dimension : 52

# %%
# --- Initialize and train SurrogateMLP via test_mlp.train_mlp ---

model = SurrogateMLP(
    input_dim=par.shape[1],
    output_dim=obs.shape[1],
    hidden_dims=HIDDEN_DIMS,
    dropout=DROPOUT_P,
    activation=ACTIVATION,
    use_layer_norm=USE_LAYER_NORM,
).to(DEVICE)

# %%
final_train_loss = train_mlp(
    model=model,
    X_train=X_train,
    y_train=y_train,
    device=DEVICE,
    max_adam_epochs=ADAM_EPOCHS,
    adam_lr=ADAM_LR,
    adam_patience=ADAM_PATIENCE,
    tol=TOL,
    max_lbfgs_iter=LBFGS_STEPS,
    loss_name=LOSS_NAME,
    train_loops=TRAIN_LOOPS,
    batch_size=BATCH_SIZE,
    loss_domain=LOSS_DOMAIN,
    par_train_raw=X_train_raw,
    logpi_targets=logpi_train,
    y_obs=y_obs,
    sigma_prior=SIGMA_PRIOR,
    sigma_lik=SIGMA_LIK,
-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1550 | loss(mse) = 3.205017e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1560 | loss(mse) = 3.033022e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1570 | loss(mse) = 3.078520e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1580 | loss(mse) = 2.948948e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1590 | loss(mse) = 2.952635e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1600 | loss(mse) = 2.958354e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1610 | loss(mse) = 3.172407e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1620 | loss(mse) = 2.979974e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1630 | loss(mse) = 3.037645e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1640 | loss(mse) = 2.886848e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1650 | loss(mse) = 2.955227e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1660 | loss(mse) = 3.002574e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1670 | loss(mse) = 2.860592e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1680 | loss(mse) = 2.819241e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1690 | loss(mse) = 2.982067e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1700 | loss(mse) = 2.890356e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1710 | loss(mse) = 2.865421e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1720 | loss(mse) = 2.847115e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1730 | loss(mse) = 3.087601e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1740 | loss(mse) = 3.068310e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1750 | loss(mse) = 2.978354e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1760 | loss(mse) = 2.909754e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1770 | loss(mse) = 2.808657e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1780 | loss(mse) = 2.843023e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1790 | loss(mse) = 2.904813e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1800 | loss(mse) = 2.939942e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1810 | loss(mse) = 2.807841e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1820 | loss(mse) = 2.857537e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1830 | loss(mse) = 2.859046e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1840 | loss(mse) = 2.898039e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1850 | loss(mse) = 2.813071e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1860 | loss(mse) = 2.840149e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1870 | loss(mse) = 2.896130e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1880 | loss(mse) = 2.855678e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1890 | loss(mse) = 2.971950e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1900 | loss(mse) = 2.938110e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1910 | loss(mse) = 2.787286e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1920 | loss(mse) = 2.821763e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1930 | loss(mse) = 2.906737e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1940 | loss(mse) = 2.836493e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1950 | loss(mse) = 2.734280e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1960 | loss(mse) = 2.792153e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1970 | loss(mse) = 2.903793e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1980 | loss(mse) = 3.001387e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 1990 | loss(mse) = 2.762511e-03 | lr = 1.100e-03
# [train][loop 1/80][Adam] epoch 2000 | loss(mse) = 2.929906e-03 | lr = 1.100e-03
# [train][loop 1/80] Starting LBFGS: max_iter=100, loss=MSE, lr=1.000e+00
# [train][loop 1/80][LBFGS] iter   1 | loss(mse) = 2.927064e-03 | lr = 1.000e+00
# [train][loop 1/80][LBFGS] iter   5 | loss(mse) = 2.812516e-03 | lr = 1.000e+00
# [train][loop 1/80][LBFGS] iter  10 | loss(mse) = 2.699898e-03 | lr = 1.000e+00
# [train][loop 1/80][LBFGS] iter  15 | loss(mse) = 2.702323e-03 | lr = 1.000e+00
# [train][loop 1/80][LBFGS] iter  20 | loss(mse) = 2.566032e-03 | lr = 1.000e+00
# [train][loop 1/80][LBFGS] iter  25 | loss(mse) = 2.679992e-03 | lr = 1.000e+00
# [train][loop 1/80][LBFGS] iter  30 | loss(mse) = 2.723320e-03 | lr = 1.000e+00
# [train][loop 1/80][LBFGS] iter  35 | loss(mse) = 2.593883e-03 | lr = 1.000e+00
# [train][loop 1/80][LBFGS] iter  40 | loss(mse) = 2.580683e-03 | lr = 1.000e+00
# [train][loop 1/80][LBFGS] iter  45 | loss(mse) = 2.709991e-03 | lr = 1.000e+00
# [train][loop 1/80][LBFGS] iter  50 | loss(mse) = 2.646848e-03 | lr = 1.000e+00
# [train][loop 1/80][LBFGS] iter  55 | loss(mse) = 2.661638e-03 | lr = 1.000e+00
# [train][loop 1/80][LBFGS] iter  60 | loss(mse) = 2.674229e-03 | lr = 1.000e+00
# [train][loop 1/80][LBFGS] iter  65 | loss(mse) = 2.522761e-03 | lr = 1.000e+00
# [train][loop 1/80][LBFGS] iter  70 | loss(mse) = 2.629196e-03 | lr = 1.000e+00
# [train][loop 1/80][LBFGS] iter  75 | loss(mse) = 2.628272e-03 | lr = 1.000e+00
# [train][loop 1/80][LBFGS] iter  80 | loss(mse) = 2.626538e-03 | lr = 1.000e+00
# [train][loop 1/80][LBFGS] iter  85 | loss(mse) = 2.606398e-03 | lr = 1.000e+00
# [train][loop 1/80][LBFGS] iter  90 | loss(mse) = 2.697012e-03 | lr = 1.000e+00
# [train][loop 1/80][LBFGS] iter  95 | loss(mse) = 2.637634e-03 | lr = 1.000e+00
# [train][loop 1/80][LBFGS] iter 100 | loss(mse) = 2.568633e-03 | lr = 1.000e+00
# [train][loop 1/80] loss=2.522761e-03 next_lr=1.100e-03 stop=completed
# [train][loop 2/80] Starting Adam: epochs=2000, loss=MSE, lr=1.100e-03, batch=45, domain=obs
# [train][loop 2/80][Adam] epoch    1 | loss(mse) = 2.712443e-03 | lr = 1.100e-03
# [train][loop 2/80][Adam] epo
-03 | lr = 1.100e-03
# [train][loop 2/80][Adam] epoch 1650 | loss(mse) = 2.420195e-03 | lr = 1.100e-03
# [train][loop 2/80][Adam] epoch 1660 | loss(mse) = 2.299753e-03 | lr = 1.100e-03
# [train][loop 2/80][Adam] epoch 1670 | loss(mse) = 2.258699e-03 | lr = 1.100e-03
# [train][loop 2/80][Adam] epoch 1680 | loss(mse) = 2.264967e-03 | lr = 1.100e-03
# [train][loop 2/80][Adam] epoch 1690 | loss(mse) = 2.401628e-03 | lr = 1.100e-03
# [train][loop 2/80][Adam] epoch 1700 | loss(mse) = 2.235650e-03 | lr = 1.100e-03
# [train][loop 2/80][Adam] epoch 1710 | loss(mse) = 2.352349e-03 | lr = 1.100e-03
# [train][loop 2/80][Adam] epoch 1720 | loss(mse) = 2.241247e-03 | lr = 1.100e-03
# [train][loop 2/80][Adam] epoch 1730 | loss(mse) = 2.273550e-03 | lr = 1.100e-03
# [train][loop 2/80][Adam] epoch 1740 | loss(mse) = 2.311504e-03 | lr = 1.100e-03
# [train][loop 2/80][Adam] epoch 1750 | loss(mse) = 2.297339e-03 | lr = 1.100e-03
# [train][loop 2/80][Adam] epoch 1760 | loss(mse) = 2.242356e-03 | lr = 1.100e-03
# [train][loop 2/80][Adam] epoch 1770 | loss(mse) = 2.234489e-03 | lr = 1.100e-03
# [train][loop 2/80][Adam] epoch 1780 | loss(mse) = 2.219541e-03 | lr = 1.100e-03
# [train][loop 2/80][Adam] epoch 1790 | loss(mse) = 2.282189e-03 | lr = 1.100e-03
# [train][loop 2/80][Adam] epoch 1800 | loss(mse) = 2.268823e-03 | lr = 1.100e-03
# [train][loop 2/80][Adam] epoch 1810 | loss(mse) = 2.269659e-03 | lr = 1.100e-03
# [train][loop 2/80][Adam] epoch 1820 | loss(mse) = 2.309120e-03 | lr = 1.100e-03
# [train][loop 2/80][Adam] epoch 1830 | loss(mse) = 2.263293e-03 | lr = 1.100e-03
# [train][loop 2/80][Adam] epoch 1840 | loss(mse) = 2.291112e-03 | lr = 1.100e-03
# [train][loop 2/80][Adam] epoch 1850 | loss(mse) = 2.297697e-03 | lr = 1.100e-03
# [train][loop 2/80][Adam] epoch 1860 | loss(mse) = 2.279466e-03 | lr = 1.100e-03
# [train][loop 2/80][Adam] epoch 1870 | loss(mse) = 2.214839e-03 | lr = 1.100e-03
# [train][loop 2/80][Adam] epoch 1880 | loss(mse) = 2.319257e-03 | lr = 1.100e-03
# [train][loop 2/80][Adam] epoch 1890 | loss(mse) = 2.523841e-03 | lr = 1.100e-03
# [train][loop 2/80][Adam] epoch 1900 | loss(mse) = 2.312412e-03 | lr = 1.100e-03
# [train][loop 2/80][Adam] epoch 1910 | loss(mse) = 2.237319e-03 | lr = 1.100e-03
# [train][loop 2/80][Adam] epoch 1920 | loss(mse) = 2.269185e-03 | lr = 1.100e-03
# [train][loop 2/80][Adam] epoch 1930 | loss(mse) = 2.243593e-03 | lr = 1.100e-03
# [train][loop 2/80][Adam] epoch 1940 | loss(mse) = 2.240918e-03 | lr = 1.100e-03
# [train][loop 2/80][Adam] epoch 1950 | loss(mse) = 2.277403e-03 | lr = 1.100e-03
# [train][loop 2/80][Adam] epoch 1960 | loss(mse) = 2.257549e-03 | lr = 1.100e-03
# [train][loop 2/80][Adam] epoch 1970 | loss(mse) = 2.250704e-03 | lr = 1.100e-03
# [train][loop 2/80][Adam] epoch 1980 | loss(mse) = 2.170261e-03 | lr = 1.100e-03
# [train][loop 2/80][Adam] epoch 1990 | loss(mse) = 2.289985e-03 | lr = 1.100e-03
# [train][loop 2/80][Adam] epoch 2000 | loss(mse) = 2.210271e-03 | lr = 1.100e-03
# [train][loop 2/80] Starting LBFGS: max_iter=100, loss=MSE, lr=1.000e+00
# [train][loop 2/80][LBFGS] iter   1 | loss(mse) = 2.285756e-03 | lr = 1.000e+00
# [train][loop 2/80][LBFGS] iter   5 | loss(mse) = 2.197372e-03 | lr = 1.000e+00
# [train][loop 2/80][LBFGS] iter  10 | loss(mse) = 2.179882e-03 | lr = 1.000e+00
# [train][loop 2/80][LBFGS] iter  15 | loss(mse) = 2.156333e-03 | lr = 1.000e+00
# [train][loop 2/80][LBFGS] iter  20 | loss(mse) = 2.177335e-03 | lr = 1.000e+00
# [train][loop 2/80][LBFGS] iter  25 | loss(mse) = 2.288096e-03 | lr = 1.000e+00
# [train][loop 2/80][LBFGS] iter  30 | loss(mse) = 2.162022e-03 | lr = 1.000e+00
# [train][loop 2/80][LBFGS] iter  35 | loss(mse) = 2.170780e-03 | lr = 1.000e+00
# [train][loop 2/80][LBFGS] iter  40 | loss(mse) = 2.228134e-03 | lr = 1.000e+00
# [train][loop 2/80][LBFGS] iter  45 | loss(mse) = 2.179984e-03 | lr = 1.000e+00
# [train][loop 2/80][LBFGS] iter  50 | loss(mse) = 2.149301e-03 | lr = 1.000e+00
# [train][loop 2/80][LBFGS] iter  55 | loss(mse) = 2.192759e-03 | lr = 1.000e+00
# [train][loop 2/80][LBFGS] iter  60 | loss(mse) = 2.147763e-03 | lr = 1.000e+00
# [train][loop 2/80][LBFGS] iter  65 | loss(mse) = 2.156150e-03 | lr = 1.000e+00
# [train][loop 2/80][LBFGS] iter  70 | loss(mse) = 2.121296e-03 | lr = 1.000e+00
# [train][loop 2/80][LBFGS] iter  75 | loss(mse) = 2.154440e-03 | lr = 1.000e+00
# [train][loop 2/80][LBFGS] iter  80 | loss(mse) = 2.124337e-03 | lr = 1.000e+00
# [train][loop 2/80][LBFGS] iter  85 | loss(mse) = 2.212170e-03 | lr = 1.000e+00
# [train][loop 2/80][LBFGS] iter  90 | loss(mse) = 2.144981e-03 | lr = 1.000e+00
# [train][loop 2/80][LBFGS] iter  95 | loss(mse) = 2.133482e-03 | lr = 1.000e+00
# [train][loop 2/80][LBFGS] iter 100 | loss(mse) = 2.155124e-03 | lr = 1.000e+00
# [train][loop 2/80] loss=2.086166e-03 next_lr=1.100e-03 stop=completed
# [train][loop 3/80] Starting Adam: epochs=2000, loss=MSE, lr=1.100e-03, batch=63, domain=obs
# [train][loop 3/80][Adam] epoch    1 | loss(mse) = 2.220620e-03 | lr = 1.100e-03
# [train][loop 3/80][Adam] epoch   10 | loss(mse) = 2.246014e-03 | lr = 1.100e-03
# [train][loop 3/80][Adam] epoch   20 | loss(mse) = 2.212413e-03 | lr = 1.100e-03
# [train][loop 3/80][Adam] epoch   30 | loss(mse) = 2.238516e-03 | lr = 1.100e-03
# [train][loop 3/80][Adam] epoch   40 | loss(mse) = 2.172765e-03 | lr = 1.100e-03
# [train][loop 3/80][Adam] epoch   50 | loss(mse) = 2.236112e-03 | lr = 1.100e-03
# [train][loop 3/80][Adam] epoch   60 | loss(mse) = 2.264835e-03 | lr = 1.100e-03
# [train][loop 3/80][Adam] epoch   70 | loss(mse) = 2.274131e-03 | lr = 1.100e-03
# [train][loop 3/80][Adam] epoch   80 | loss(mse) = 2.223709e-03 | lr = 1.100e-03
# [train][loop 3/80][Adam] epoch   90 | loss(mse) = 2.274523e-03 | lr = 1.100e-03
# [train][loop 3/80][Adam] epoch  100 | loss(mse) = 2.195899e-03 | lr = 1.100e-03
# [train][loop 3/80][Adam] epoch
-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  560 | loss(mse) = 1.656996e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  570 | loss(mse) = 1.636554e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  580 | loss(mse) = 1.637236e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  590 | loss(mse) = 1.671346e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  600 | loss(mse) = 1.602245e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  610 | loss(mse) = 1.659785e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  620 | loss(mse) = 1.644427e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  630 | loss(mse) = 1.623873e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  640 | loss(mse) = 1.596227e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  650 | loss(mse) = 1.596863e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  660 | loss(mse) = 1.599705e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  670 | loss(mse) = 1.632974e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  680 | loss(mse) = 1.656473e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  690 | loss(mse) = 1.645093e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  700 | loss(mse) = 1.662852e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  710 | loss(mse) = 1.610838e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  720 | loss(mse) = 1.579462e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  730 | loss(mse) = 1.630515e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  740 | loss(mse) = 1.623864e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  750 | loss(mse) = 1.614262e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  760 | loss(mse) = 1.643243e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  770 | loss(mse) = 1.606705e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  780 | loss(mse) = 1.636647e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  790 | loss(mse) = 1.625497e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  800 | loss(mse) = 1.591666e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  810 | loss(mse) = 1.618118e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  820 | loss(mse) = 1.664179e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  830 | loss(mse) = 1.668447e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  840 | loss(mse) = 1.577750e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  850 | loss(mse) = 1.584811e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  860 | loss(mse) = 1.644188e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  870 | loss(mse) = 1.656946e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  880 | loss(mse) = 1.607720e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  890 | loss(mse) = 1.633070e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  900 | loss(mse) = 1.640928e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  910 | loss(mse) = 1.629249e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  920 | loss(mse) = 1.585388e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  930 | loss(mse) = 1.642819e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  940 | loss(mse) = 1.612062e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  950 | loss(mse) = 1.626589e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  960 | loss(mse) = 1.639204e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  970 | loss(mse) = 1.616269e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  980 | loss(mse) = 1.605707e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch  990 | loss(mse) = 1.642720e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] epoch 1000 | loss(mse) = 1.631947e-03 | lr = 4.297e-06
# [train][loop 10/80][Adam] plateau at epoch 1000, reducing LR to 1.074e-06 and stopping early.
# [train][loop 10/80] Starting LBFGS: max_iter=100, loss=MSE, lr=1.000e+00
# [train][loop 10/80][LBFGS] iter   1 | loss(mse) = 1.647034e-03 | lr = 1.000e+00
# [train][loop 10/80][LBFGS] iter   5 | loss(mse) = 1.679788e-03 | lr = 1.000e+00
# [train][loop 10/80][LBFGS] iter  10 | loss(mse) = 1.642158e-03 | lr = 1.000e+00
# [train][loop 10/80][LBFGS] iter  15 | loss(mse) = 1.632617e-03 | lr = 1.000e+00
# [train][loop 10/80][LBFGS] iter  20 | loss(mse) = 1.667056e-03 | lr = 1.000e+00
# [train][loop 10/80][LBFGS] iter  25 | loss(mse) = 1.629629e-03 | lr = 1.000e+00
# [train][loop 10/80][LBFGS] iter  30 | loss(mse) = 1.635725e-03 | lr = 1.000e+00
# [train][loop 10/80][LBFGS] iter  35 | loss(mse) = 1.612790e-03 | lr = 1.000e+00
# [train][loop 10/80][LBFGS] iter  40 | loss(mse) = 1.641787e-03 | lr = 1.000e+00
# [train][loop 10/80][LBFGS] iter  45 | loss(mse) = 1.593901e-03 | lr = 1.000e+00
# [train][loop 10/80][LBFGS] iter  50 | loss(mse) = 1.617648e-03 | lr = 1.000e+00
# [train][loop 10/80][LBFGS] iter  55 | loss(mse) = 1.632757e-03 | lr = 1.000e+00
# [train][loop 10/80][LBFGS] iter  60 | loss(mse) = 1.656955e-03 | lr = 1.000e+00
# [train][loop 10/80][LBFGS] iter  65 | loss(mse) = 1.626401e-03 | lr = 1.000e+00
# [train][loop 10/80][LBFGS] iter  70 | loss(mse) = 1.612741e-03 | lr = 1.000e+00
# [train][loop 10/80][LBFGS] iter  75 | loss(mse) = 1.587497e-03 | lr = 1.000e+00
# [train][loop 10/80][LBFGS] iter  80 | loss(mse) = 1.643359e-03 | lr = 1.000e+00
# [train][loop 10/80][LBFGS] iter  85 | loss(mse) = 1.650076e-03 | lr = 1.000e+00
# [train][loop 10/80][LBFGS] iter  90 | loss(mse) = 1.674965e-03 | lr = 1.000e+00
# [train][loop 10/80][LBFGS] iter  95 | loss(mse) = 1.623276e-03 | lr = 1.000e+00
# [train][loop 10/80][LBFGS] iter 100 | loss(mse) = 1.648009e-03 | lr = 1.000e+00
# [train][loop 10/80] loss=1.549011e-03 next_lr=1.074e-06 stop=adam_plateau
# [train][loop 11/80] Starting Adam: epochs=2000, loss=MSE, lr=1.074e-06, batch=926, domain=obs
# [train][loop 11/80][Adam] epoch    1 | loss(mse) = 1.573585e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch   10 | loss(mse) = 1.603476e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch   20 | loss(mse) = 1.646249e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch   30 | loss(mse) = 1.629437e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch   40 | loss(mse) = 1.626433e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch   50 | loss(mse) = 1.611430e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch   60 | loss(mse) = 1.618392e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch   70 | loss(mse) = 1.599690e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch   80 | loss(mse) = 1.624463e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch   90 | loss(mse) = 1.635183e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  100 | loss(mse) = 1.670285e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  110 | loss(mse) = 1.635049e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  120 | loss(mse) = 1.638465e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  130 | loss(mse) = 1.644968e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  140 | loss(mse) = 1.680960e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  150 | loss(mse) = 1.624127e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  160 | loss(mse) = 1.607781e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  170 | loss(mse) = 1.669166e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  180 | loss(mse) = 1.615954e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  190 | loss(mse) = 1.645954e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  200 | loss(mse) = 1.667079e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  210 | loss(mse) = 1.597137e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  220 | loss(mse) = 1.617650e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  230 | loss(mse) = 1.621319e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  240 | loss(mse) = 1.621866e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  250 | loss(mse) = 1.620159e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  260 | loss(mse) = 1.619865e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  270 | loss(mse) = 1.578295e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  280 | loss(mse) = 1.618888e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  290 | loss(mse) = 1.590658e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  300 | loss(mse) = 1.637963e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  310 | loss(mse) = 1.626106e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  320 | loss(mse) = 1.631399e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  330 | loss(mse) = 1.631228e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  340 | loss(mse) = 1.610103e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  350 | loss(mse) = 1.641436e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  360 | loss(mse) = 1.642427e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  370 | loss(mse) = 1.615271e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  380 | loss(mse) = 1.630417e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  390 | loss(mse) = 1.671790e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  400 | loss(mse) = 1.643223e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  410 | loss(mse) = 1.611996e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  420 | loss(mse) = 1.632725e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  430 | loss(mse) = 1.619319e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  440 | loss(mse) = 1.614949e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  450 | loss(mse) = 1.616678e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  460 | loss(mse) = 1.639909e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  470 | loss(mse) = 1.624358e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  480 | loss(mse) = 1.628326e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  490 | loss(mse) = 1.594332e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  500 | loss(mse) = 1.622191e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  510 | loss(mse) = 1.640831e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  520 | loss(mse) = 1.609951e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  530 | loss(mse) = 1.600857e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  540 | loss(mse) = 1.611387e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  550 | loss(mse) = 1.582068e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  560 | loss(mse) = 1.605644e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  570 | loss(mse) = 1.642094e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  580 | loss(mse) = 1.606746e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  590 | loss(mse) = 1.597984e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  600 | loss(mse) = 1.572529e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  610 | loss(mse) = 1.654138e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  620 | loss(mse) = 1.588448e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  630 | loss(mse) = 1.589157e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  640 | loss(mse) = 1.580762e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  650 | loss(mse) = 1.609579e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  660 | loss(mse) = 1.653399e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  670 | loss(mse) = 1.638923e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  680 | loss(mse) = 1.595922e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  690 | loss(mse) = 1.675430e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  700 | loss(mse) = 1.646970e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  710 | loss(mse) = 1.586290e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  720 | loss(mse) = 1.643138e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  730 | loss(mse) = 1.633671e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  740 | loss(mse) = 1.558597e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  750 | loss(mse) = 1.631480e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  760 | loss(mse) = 1.606039e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  770 | loss(mse) = 1.585548e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  780 | loss(mse) = 1.608292e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  790 | loss(mse) = 1.577598e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  800 | loss(mse) = 1.636427e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  810 | loss(mse) = 1.636253e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  820 | loss(mse) = 1.620380e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  830 | loss(mse) = 1.639678e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  840 | loss(mse) = 1.596180e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  850 | loss(mse) = 1.648418e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  860 | loss(mse) = 1.627815e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  870 | loss(mse) = 1.612885e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  880 | loss(mse) = 1.652012e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  890 | loss(mse) = 1.639191e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  900 | loss(mse) = 1.649179e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  910 | loss(mse) = 1.652982e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  920 | loss(mse) = 1.636450e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  930 | loss(mse) = 1.595907e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  940 | loss(mse) = 1.677859e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  950 | loss(mse) = 1.632899e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  960 | loss(mse) = 1.648106e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  970 | loss(mse) = 1.703146e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  980 | loss(mse) = 1.646895e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch  990 | loss(mse) = 1.666006e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] epoch 1000 | loss(mse) = 1.631853e-03 | lr = 1.074e-06
# [train][loop 11/80][Adam] plateau at epoch 1000, reducing LR to 2.686e-07 and stopping early.
# LR 2.686e-07 below 1e-6 threshold; terminating training early.
# [train][loop 11/80] loss=1.549011e-03 next_lr=2.686e-07 stop=adam_lr_min
# Final training loss (mse): 1.549011e-03

# %%
# --- Compute L1 logpi error on chain tail (index >= tail_start) ---

tail_len = chain.shape[0] - EVAL_TAIL_START
if tail_len <= 0:
    raise ValueError('EVAL_TAIL_START must be smaller than the chain length.')

tail_l1 = compute_logpi_l1_error(
    model=model,
    par=par,
    logpi_true=logpi_true,
    chain=chain,
    props=props,
    val_start=EVAL_TAIL_START,
    val_len=tail_len,
    x_mean=x_mean,
    x_std=x_std,
    y_obs=y_obs,
    sigma_prior=SIGMA_PRIOR,
    sigma_lik=SIGMA_LIK,
    device=DEVICE,
)

print(f'L1 logpi error on chain tail [{EVAL_TAIL_START}, end): {tail_l1:.6f}')
# Out:
# L1 logpi error on chain tail [50000, end): 3.742622

# %% [markdown]
# 5.242563
# 4.899523
# v4.232338
#
#
# iteration,train_limit,base_hidden_sizes,final_hidden_sizes,val_error,master_val_error,growth_steps,final_train_loss
# 1,2000,[8],"[8, 8]",5.867817679563296,7.095813837634286,1,0.08197729289531708
# 2,4000,"[8, 8]","[16, 32]",4.594648975642015,4.918739791627595,3,0.07835499197244644
# 3,6000,"[16, 32]","[16, 32]",4.907302817124111,4.165183718501073,0,0.05713796243071556
# 4,8000,"[16, 32]","[32, 32]",3.5517553089907246,3.359570796361799,1,0.058842990547418594
# 5,10000,"[32, 32]","[64, 64]",2.4533132625766885,2.6955348713135168,2,0.0424831286072731
# 6,12000,"[64, 64]","[64, 64]",2.5594358762574174,2.5561185208652413,0,0.028931600973010063
# 7,14000,"[64, 64]","[64, 64]",2.175952113928763,2.2197988679717255,0,0.027288204059004784
# 8,16000,"[64, 64]","[64, 64]",1.9016387067773832,2.331814047863837,0,0.028165634721517563
# 9,18000,"[64, 64]","[64, 64, 64]",1.9504109285714764,1.7103362801803619,1,0.026211336255073547
# 10,20000,"[64, 64, 64]","[64, 64, 64]",2.2927826321948723,1.6362665044396796,0,0.019929099828004837
# 11,22000,"[64, 64, 64]","[64, 64, 64, 64]",1.977168851832621,1.6241933904734225,1,0.019994590431451797
